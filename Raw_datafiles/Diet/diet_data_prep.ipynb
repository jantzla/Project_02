# %% [markdown]
# # National Health and Nutrition Examination Survey
# Data from 1990-2020

# %%
# Libaries
import pandas as pd
import numpy as np
import xport
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import pymysql
from sqlalchemy import create_engine

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Dietarty Data

# %%
# 1999-2000
with open(r"C:\Users\ljant\Downloads\DRXTOT.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_00.csv', index=False)
df_00 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_00.csv")
df_00['year'] = df_00['year'] = 2000

# %%
# 2001-2002
with open(r"C:\Users\ljant\Downloads\DRXTOT_B.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_02.csv', index=False)
df_02 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_02.csv")
df_02['year'] = df_00['year'] = 2002

# %%
# 2003-2004
with open(r"C:\Users\ljant\Downloads\DR1TOT_C.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_04.csv', index=False)
df_04 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_04.csv")
df_04['year'] = df_04['year'] = 2004

# %%
# 2005-2006
with open(r"C:\Users\ljant\Downloads\DR1TOT_D.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_06.csv', index=False)
df_06 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_06.csv")
df_06['year'] = df_06['year'] = 2006

# %%
# 2007-2008
with open(r"C:\Users\ljant\Downloads\DR1TOT_E.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_08.csv', index=False)
df_08 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_08.csv")
df_08['year'] = df_08['year'] = 2008

# %%
# 2009-2010
with open(r"C:\Users\ljant\Downloads\DR1TOT_F.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_10.csv', index=False)
df_10 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_10.csv")
df_10['year'] = df_10['year'] = 2010

# %%
# 2011-2012
with open(r"C:\Users\ljant\Downloads\DR1TOT_G.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_12.csv', index=False)
df_12 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_12.csv")
df_12['year'] = df_12['year'] = 2012

# %%
# 2013-2014
with open(r"C:\Users\ljant\Downloads\DR1TOT_H.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_14.csv', index=False)
df_14 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_14.csv")
df_14['year'] = df_14['year'] = 2014

# %%
# 2015-2016
with open(r"C:\Users\ljant\Downloads\DR1TOT_I.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_16.csv', index=False)
df_16 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_16.csv")
df_16['year'] = df_16['year'] = 2016

# %%
# 2017-2020
with open(r"C:\Users\ljant\Downloads\P_DR1TOT.XPT", 'rb') as f: df = xport.to_dataframe(f)
df.to_csv('diet_file_20.csv', index=False)
df_20 = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\Projects\Project_2\Raw_datafiles\Diet\diet_file_20.csv")
df_20['year'] = df_20['year'] = 2020

# %%
# Getting only the columns I need.
col_decoder = {
    'SEQN' : 'patient_id',
    'year': 'year', 
    'DRXTPROT': 'protein',
    'DRXTFIBE': 'fiber',
    'DRXTSFAT': 'sattuarated_fatty_acids',
    'DRXTMFAT': 'monounsaturated_fatty_acids',
    'DRXTPFAT': 'polyunsaturated_fatty_acids',
    'DRXTCHOL': 'cholesterol',
    'DRXTCARO': 'carotene',
    'DRXTVAIU': 'vitamin_a',
    'DRXTVB1': 'vitamin_b1',
    'DRXTVB2': 'vitamin_b2',
    'DRXTVB6': 'vitamin_b6',
    'DRXTVB12': 'vitamin_b12',    
    'DRXTVC': 'vitamin_c',
    'DRXTVE': 'vitamin_e',
    'DRXTFOLA': 'folate',
    'DRXTCALC': 'calcium',
    'DRXTPHOS': 'phosporus',
    'DRXTMAGN': 'magnesium',
    'DRXTIRON': 'iron',
    'DRXTZINC': 'zinc',
    'DRXTCOPP': 'copper',
    'DRDTSODI': 'sodium',
    'DRXTPOTA': 'potassium',
    'DRXTSELE': 'selenium',
    'DRXTCAFF': 'caffeine',
    'DRXTALCO': 'alcohol',
    'DRD320GW': 'water' 
}
df_00 = df_00[list(col_decoder.keys())].rename(columns=col_decoder)

# %%
# Part II
col_decoder = {
    'SEQN' : 'patient_id',
    'year': 'year', 
    'DRXTPROT': 'protein',
    'DRXTFIBE': 'fiber',
    'DRXTSFAT': 'sattuarated_fatty_acids',
    'DRXTMFAT': 'monounsaturated_fatty_acids',
    'DRXTPFAT': 'polyunsaturated_fatty_acids',
    'DRXTCHOL': 'cholesterol',
    'DRXTACAR': 'a_carotene',
    'DRXTBCAR': 'b_carotene',
    'DRXTVARA': 'vitamin_a',
    'DRXTVB1': 'vitamin_b1',
    'DRXTVB2': 'vitamin_b2',
    'DRXTVB6': 'vitamin_b6',
    'DRXTVB12': 'vitamin_b12',    
    'DRXTVC': 'vitamin_c',
    'DRXTATOC': 'vitamin_e',
    'DRXTFOLA': 'folate',
    'DRXTCALC': 'calcium',
    'DRXTPHOS': 'phosporus',
    'DRXTMAGN': 'magnesium',
    'DRXTIRON': 'iron',
    'DRXTZINC': 'zinc',
    'DRXTCOPP': 'copper',
    'DRDTSODI': 'sodium',
    'DRXTPOTA': 'potassium',
    'DRXTSELE': 'selenium',
    'DRXTCAFF': 'caffeine',
    'DRXTALCO': 'alcohol',
    'DRD320GW': 'water' 
}
df_02 = df_02[list(col_decoder.keys())].rename(columns=col_decoder)

# %%
# Part III
col_decoder = {
    'SEQN' : 'patient_id',
    'year': 'year',
    'DR1TPROT': 'protein',
    'DR1TFIBE': 'fiber',
    'DR1TSFAT': 'sattuarated_fatty_acids',
    'DR1TMFAT': 'monounsaturated_fatty_acids',
    'DR1TPFAT': 'polyunsaturated_fatty_acids',
    'DR1TCHOL': 'cholesterol',
    'DR1TACAR': 'a_carotene',
    'DR1TBCAR': 'b_carotene',
    'DR1TVARA': 'vitamin_a',
    'DR1TVB1': 'vitamin_b1',
    'DR1TVB2': 'vitamin_b2',
    'DR1TVB6': 'vitamin_b6',
    'DR1TVB12': 'vitamin_b12',    
    'DR1TVC': 'vitamin_c',
    'DR1TATOC': 'vitamin_e',
    'DR1TFOLA': 'folate',
    'DR1TCALC': 'calcium',
    'DR1TPHOS': 'phosporus',
    'DR1TMAGN': 'magnesium',
    'DR1TIRON': 'iron',
    'DR1TZINC': 'zinc',
    'DR1TCOPP': 'copper',
    'DR1TSODI': 'sodium',
    'DR1TPOTA': 'potassium',
    'DR1TSELE': 'selenium',
    'DR1TCAFF': 'caffeine',
    'DR1TALCO': 'alcohol',
    'DR1_320': 'water' 
}

df_04 = df_04[list(col_decoder.keys())].rename(columns=col_decoder)

# %%
# Part IV
col_decoder = {
    'SEQN' : 'patient_id',
    'year': 'year', 
    'DR1TPROT': 'protein',
    'DR1TFIBE': 'fiber',
    'DR1TSFAT': 'sattuarated_fatty_acids',
    'DR1TMFAT': 'monounsaturated_fatty_acids',
    'DR1TPFAT': 'polyunsaturated_fatty_acids',
    'DR1TCHOL': 'cholesterol',
    'DR1TACAR': 'a_carotene',
    'DR1TBCAR': 'b_carotene',
    'DR1TVARA': 'vitamin_a',
    'DR1TVB1': 'vitamin_b1',
    'DR1TVB2': 'vitamin_b2',
    'DR1TVB6': 'vitamin_b6',
    'DR1TVB12': 'vitamin_b12',    
    'DR1TVC': 'vitamin_c',
    'DR1TATOC': 'vitamin_e',
    'DR1TFOLA': 'folate',
    'DR1TCALC': 'calcium',
    'DR1TPHOS': 'phosporus',
    'DR1TMAGN': 'magnesium',
    'DR1TIRON': 'iron',
    'DR1TZINC': 'zinc',
    'DR1TCOPP': 'copper',
    'DR1TSODI': 'sodium',
    'DR1TPOTA': 'potassium',
    'DR1TSELE': 'selenium',
    'DR1TCAFF': 'caffeine',
    'DR1TALCO': 'alcohol',
    'DR1_330Z': 'water' 
}

df_06 = df_06[list(col_decoder.keys())].rename(columns=col_decoder)

# %%
# Part V
col_decoder = {
    'SEQN' : 'patient_id',
    'year': 'year', 
    'DRQSDIET': 'special_diet',
    'DR1TPROT': 'protein',
    'DR1TSUGR': 'total_sugars',
    'DR1TFIBE': 'fiber',
    'DR1TSFAT': 'sattuarated_fatty_acids',
    'DR1TMFAT': 'monounsaturated_fatty_acids',
    'DR1TPFAT': 'polyunsaturated_fatty_acids',
    'DR1TCHOL': 'cholesterol',
    'DR1TACAR': 'a_carotene',
    'DR1TBCAR': 'b_carotene',
    'DR1TVARA': 'vitamin_a',
    'DR1TVB1': 'vitamin_b1',
    'DR1TVB2': 'vitamin_b2',
    'DR1TVB6': 'vitamin_b6',
    'DR1TVB12': 'vitamin_b12',    
    'DR1TVC': 'vitamin_c',
    'DR1TVD': 'vitamin_d',
    'DR1TATOC': 'vitamin_e',
    'DR1TVK': 'vitamin_k',
    'DR1TFOLA': 'folate',
    'DR1TCHL': 'choline',
    'DR1TCALC': 'calcium',
    'DR1TPHOS': 'phosporus',
    'DR1TMAGN': 'magnesium',
    'DR1TIRON': 'iron',
    'DR1TZINC': 'zinc',
    'DR1TCOPP': 'copper',
    'DR1TSODI': 'sodium',
    'DR1TPOTA': 'potassium',
    'DR1TSELE': 'selenium',
    'DR1TCAFF': 'caffeine',
    'DR1TALCO': 'alcohol',
    'DR1_320Z': 'water' 
}

df_08 = df_08[list(col_decoder.keys())].rename(columns=col_decoder)
df_10 = df_10[list(col_decoder.keys())].rename(columns=col_decoder)
df_12 = df_12[list(col_decoder.keys())].rename(columns=col_decoder)
df_14 = df_14[list(col_decoder.keys())].rename(columns=col_decoder)
df_16 = df_16[list(col_decoder.keys())].rename(columns=col_decoder)
df_20 = df_20[list(col_decoder.keys())].rename(columns=col_decoder)

# %%
df_diet = pd.concat([df_00,
                    df_02,
                    df_04,
                    df_06,
                    df_08,
                    df_10,
                    df_12,
                    df_14,
                    df_16,
                    df_20]).reset_index(drop = True)
df_diet
# Out:
#         patient_id  year  protein  fiber  sattuarated_fatty_acids  \
# 0              1.0  2002    31.96   7.41                    9.400
# 1              2.0  2002   123.16  36.99                   24.340
# 2              3.0  2002    40.19  11.16                   15.610
# 3              4.0  2002    56.16   5.45                   27.540
# 4              5.0  2002    97.13  17.28                   36.000
# ...            ...   ...      ...    ...                      ...
# 102357    124818.0  2020    58.05  15.00                   62.115
# 102358    124819.0  2020    67.43   8.30                   32.515
# 102359    124820.0  2020    39.32  12.30                   15.558
# 102360    124821.0  2020   138.10   6.70                   15.733
# 102361    124822.0  2020      NaN    NaN                      NaN
#
#         monounsaturated_fatty_acids  polyunsaturated_fatty_acids  cholesterol  \
# 0                             9.000                        6.400        46.55
# ...

# %%
df_diet.to_csv('diet_python.csv', index=False)
